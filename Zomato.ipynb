# %%
# Libraries:
import matplotlib.pyplot as plt

import matplotlib
from matplotlib import pyplot as plt

import pandas as pd

import seaborn as sns

import numpy as np

# %% [markdown]
# # PART – 1 : (Systematic Appearance of a Dataset)
#
# # 1.Load the Data set in the Required Format

# %%
df_zomato = pd.read_csv('zomato.csv')
df_zomato
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %% [markdown]
# # 2.Check the Shape of the Dataset

# %%
df_zomato.shape
# Out:
# (51717, 17)

# %% [markdown]
# # 3.Check for Data Types of Each Column

# %%
df_zomato.dtypes
# Out:
# url                            object
# address                        object
# name                           object
# online_order                   object
# book_table                     object
# rate                           object
# votes                           int64
# phone                          object
# location                       object
# rest_type                      object
# dish_liked                     object
# cuisines                       object
# approx_cost(for two people)    object
# reviews_list                   object
# menu_item                      object
# listed_in(type)                object
# listed_in(city)                object
# dtype: object

# %% [markdown]
# # 6.Sanity Check to provide First Five rows of the Dataset

# %%
df_zomato.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %% [markdown]
# # 7.Check for Duplicates and Removal of Duplicate Values

# %%
df_zomato.duplicated(keep = False)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51712    False
# 51713    False
# 51714    False
# 51715    False
# 51716    False
# Length: 51717, dtype: bool

# %%
df_zomato.drop_duplicates(inplace = True)

# %%
df_zomato
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %% [markdown]
# # 8.Get the Count of Missing Value

# %%
missing_values_count = df_zomato.isnull().sum()
missing_values_count
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %% [markdown]
# # 9.Total Percentage of Missing Values

# %%
df_zomato.shape[0]
# Out:
# 51717

# %%
df_zomato.shape[1]
# Out:
# 17

# %%
# Here shape[0] Means Rows,shape[1] Means Columns:
total_missing_percentage = (df_zomato.isnull().sum().sum() / (df_zomato.shape[0] * df_zomato.shape[1])) * 100
total_missing_percentage
# Out:
# 4.288042730288937

# %% [markdown]
# # 10.Concatenate the Total Missing Values and Percentage of Missing Values to form a Data Frame

# %%
missing_values_count = df_zomato.isnull().sum()
missing_values_count
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
missing_values_percentage = (df_zomato.isnull().sum() / len(df_zomato)) * 100
missing_values_percentage
# Out:
# url                             0.000000
# address                         0.000000
# name                            0.000000
# online_order                    0.000000
# book_table                      0.000000
# rate                           15.033741
# votes                           0.000000
# phone                           2.335789
# location                        0.040606
# rest_type                       0.438927
# dish_liked                     54.291626
# cuisines                        0.087012
# approx_cost(for two people)     0.669026
# reviews_list                    0.000000
# menu_item                       0.000000
# listed_in(type)                 0.000000
# listed_in(city)                 0.000000
# dtype: float64

# %%
missing_values_df = pd.DataFrame({
    'Total Missing Values': missing_values_count,
    'Percentage of Missing Values': missing_values_percentage
})
print("Total Missing Values and Percentage:")
missing_values_df
# Out:
# Total Missing Values and Percentage:
#                              Total Missing Values  \
# url                                             0
# address                                         0
# name                                            0
# online_order                                    0
# book_table                                      0
# rate                                         7775
# votes                                           0
# phone                                        1208
# location                                       21
# rest_type                                     227
# dish_liked                                  28078
# cuisines                                       45
# approx_cost(for two people)                   346
# reviews_list                                    0
# menu_item                                       0
# listed_in(type)                                 0
# listed_in(city)                                 0
#
# ...

# %% [markdown]
# # Remove NaN Values from the Dataset

# %%
# For Rows
df_nan_rows = df_zomato.dropna(inplace = True)
df_nan_rows

# %%
# For Columns 
df_nan_columns = df_zomato.dropna(axis=1,inplace = True)
df_nan_columns

# %%
df_zomato.isnull().sum()
# Out:
# url                            0
# address                        0
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# phone                          0
# location                       0
# rest_type                      0
# dish_liked                     0
# cuisines                       0
# approx_cost(for two people)    0
# reviews_list                   0
# menu_item                      0
# listed_in(type)                0
# listed_in(city)                0
# dtype: int64

# %%
df_zomato
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51705  https://www.zomato.com/bangalore/izakaya-gastr...
# 51707  https://www.zomato.com/bangalore/m-bar-bengalu...
# 51708  https://www.zomato.com/bangalore/keys-cafe-key...
# 51711  https://www.zomato.com/bangalore/bhagini-2-whi...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
df_zomato.dtypes
# Out:
# url                            object
# address                        object
# name                           object
# online_order                   object
# book_table                     object
# rate                           object
# votes                           int64
# phone                          object
# location                       object
# rest_type                      object
# dish_liked                     object
# cuisines                       object
# approx_cost(for two people)    object
# reviews_list                   object
# menu_item                      object
# listed_in(type)                object
# listed_in(city)                object
# dtype: object

# %% [markdown]
# # 15.Change the Column type based on its own Origin

# %%
df_zomato['votes'] = df_zomato['votes'].astype(int)
df_zomato['approx_cost(for two people)'] = df_zomato['approx_cost(for two people)'].str.replace(',', '').astype(float)
df_zomato['approx_cost(for two people)'] = df_zomato['approx_cost(for two people)'].astype(int)
df_zomato['votes']
df_zomato['approx_cost(for two people)']
# Out:
# 0         800
# 1         800
# 2         800
# 3         300
# 4         600
#          ...
# 51705    1200
# 51707    2000
# 51708    1200
# 51711     800
# 51715    2500
# Name: approx_cost(for two people), Length: 23193, dtype: int32

# %%
df_zomato
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51705  https://www.zomato.com/bangalore/izakaya-gastr...
# 51707  https://www.zomato.com/bangalore/m-bar-bengalu...
# 51708  https://www.zomato.com/bangalore/keys-cafe-key...
# 51711  https://www.zomato.com/bangalore/bhagini-2-whi...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %% [markdown]
# # PART – 2 : (Data Analysis)
#
#
# # 1.Plot the Analysis – What is the Percentage of Restaurants that Accepts Online Orders by using Appropriate Plotting??

# %%
online_order_counts = df_zomato['online_order'].value_counts()


percentage_online_order = (online_order_counts / len(df_zomato)) * 100


plt.figure(figsize=(8, 6))
percentage_online_order.plot(kind='bar', color=['skyblue', 'salmon'], edgecolor='black')
plt.title('Percentage of Restaurants Accepting Online Orders')
plt.xlabel('Online Order Availability')
plt.ylabel('Percentage')
plt.xticks(rotation=0)
plt.ylim(0, 100)
plt.show()

# %% [markdown]
# # 2. What is the most common restaurant type and which type has the highest average rating – State the Output with best Plotting??

# %%
df_rest_type_rating = df_zomato[['rest_type', 'rate']]

df_rest_type_rating['rate'] = df_rest_type_rating['rate'].str.extract('(\d+\.\d+)').astype(float)

# Most common restaurant type
most_common_rest_type = df_rest_type_rating['rest_type'].mode()[0]

# Restaurant type with the highest average rating
avg_rating_by_rest_type = df_rest_type_rating.groupby('rest_type')['rate'].mean()
highest_avg_rating_type = avg_rating_by_rest_type.idxmax()


plt.figure(figsize=(12, 6))
sns.countplot(x='rest_type', data=df_rest_type_rating, order=df_rest_type_rating['rest_type'].value_counts().index)
plt.title('Most Common Restaurant Type')
plt.xlabel('Restaurant Type')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()


plt.figure(figsize=(12, 6))
sns.barplot(x=avg_rating_by_rest_type.index, y=avg_rating_by_rest_type.values, order=avg_rating_by_rest_type.sort_values(ascending=False).index)
plt.title('Average Rating by Restaurant Type')
plt.xlabel('Restaurant Type')
plt.ylabel('Average Rating')
plt.xticks(rotation=90)
plt.show()

print(f"\nMost Common Restaurant Type: {most_common_rest_type}")
print(f"Restaurant Type with Highest Average Rating: {highest_avg_rating_type}")
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_15976\1157327212.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rest_type_rating['rate'] = df_rest_type_rating['rate'].str.extract('(\d+\.\d+)').astype(float)
# Most Common Restaurant Type: Casual Dining
# Restaurant Type with Highest Average Rating: Pub, Cafe

# %%
print("Descriptive Statistics for Numerical Columns:")
numerical_stats = df_zomato.describe()
numerical_stats
# Out:
# Descriptive Statistics for Numerical Columns:
#               votes  approx_cost(for two people)
# count  23193.000000                 23193.000000
# mean     601.074462                   755.904368
# std     1114.854301                   521.448320
# min        0.000000                    40.000000
# 25%      101.000000                   400.000000
# 50%      221.000000                   600.000000
# 75%      586.000000                  1000.000000
# max    16832.000000                  6000.000000

# %% [markdown]
# # Check for Distribution of the Dataset with Skewness and Kurtosis

# %%
distribution_stats[column] = [skewness, kurt]
distribution_stats
# Out:
#           approx_cost(for two people)
# Skewness                     2.018772
# Kurtosis                     6.468292

# %% [markdown]
# # 5.Interpreted Correlation of each numerical column by means of appropriate plot

# %%
correlation = df_zomato.corr()

# Heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation')
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_15976\4101754981.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df_zomato.corr()

# %% [markdown]
# # Univariate, Bi-Variate and Multi Variate Analysis

# %%
# Univariate

sns.histplot(df_zomato['rate'], kde=True)
plt.title('Univariate Analysis - Rating Distribution')
plt.show()

# %%
# Bivariate analysis for two variables

plt.scatter(df_zomato['votes'], df_zomato['rate'])
plt.title('Bivariate Analysis')
plt.xlabel('Votes')
plt.ylabel('Rating')
plt.show()

# %%
# Multivariate
sns.pairplot(df_zomato[['votes', 'rate', 'approx_cost(for two people)']])
plt.suptitle('Multivariate Analysis - Pairs Plot', y=1.02)
plt.show()
